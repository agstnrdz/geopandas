# %% [markdown]
# #### Cartografía de las denuncias registradas por ruidos molestos entre 2021 y 2024.
# Fuente: Subsecretaría de Ambiente
# Para representar estos objetos en ```gpd.explore()``` estos deben estar proyectados en un sistema de referencia de coordenadas geocéntricos. En este caso, los objetos están proyectados en un sistema de referencia de coordenadas geodésico (local).

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib
import h3

# %%
ruidos = gpd.read_file(r"C:\Users\UserMCR\Desktop\Agustín\GIS\2025 ambiente - ruidos molestos\2025 resultados\ambiente_ruidos_2025\denuncias_posgar.gpkg")
ruidos.plot("Total denuncias")
# Out:
# <Axes: >
